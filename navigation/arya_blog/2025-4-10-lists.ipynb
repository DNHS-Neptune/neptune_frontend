# %% [markdown]
# ---
# layout: post
# title: Lists Popcorn + Hw Hacks
# description: homework idk
# type: issues
# comments: true
# permalink: /navigation/arya_blog/binary
# ---

# %% [markdown]
# # PopCorn Hack 1: Find Students with Scores in a Range

# %%
def find_students_in_range(df, min_score, max_score):
    return df[(df['Score'] >= min_score) & (df['Score'] <= max_score)]
    
students_in_range = find_students_in_range(student_data, 80, 90)
print(students_in_range)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 def find_students_in_range(df, min_score, max_score):
#       2     return df[(df['Score'] >= min_score) & (df['Score'] <= max_score)]
# ----> 4 students_in_range = find_students_in_range(student_data, 80, 90)
#       5 print(students_in_range)
#
# NameError: name 'student_data' is not defined
