# %% [markdown]
# ---
# layout: post
# title: Lists Popcorn + Hw Hacks
# description: homework idk
# type: issues
# comments: true
# permalink: /navigation/arya_blog/binary
# ---

# %% [markdown]
# # PopCorn Hack 1: Find Students with Scores in a Range

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
def find_students_in_range(df, min_score, max_score):
    return df[(df['Score'] >= min_score) & (df['Score'] <= max_score)]

student_data = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Score': [85, 92, 78, 88]
})

find_students_in_range(student_data, 80, 90)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       4 def find_students_in_range(df, min_score, max_score):
#       5     return df[(df['Score'] >= min_score) & (df['Score'] <= max_score)]
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # PopCorn Hack 2: Add Letter Grades Based on Score

# %%
def add_letter_grades(df):
    def get_letter(score):
        if score >= 90:
            return 'A'
        elif score >= 80:
            return 'B'
        elif score >= 70:
            return 'C'
        elif score >= 60:
            return 'D'
        else:
            return 'F'
    df['Letter'] = df['Score'].apply(get_letter)
    return df


add_letter_grades(student_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 17
#      13     df['Letter'] = df['Score'].apply(get_letter)
#      14     return df
# ---> 17 add_letter_grades(student_data)
#
# NameError: name 'student_data' is not defined
